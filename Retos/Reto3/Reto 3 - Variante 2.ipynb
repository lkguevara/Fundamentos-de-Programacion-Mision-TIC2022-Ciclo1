# %%
 to_es = {'-': 'T',
 '--': 'M',
 '---': 'O',
 '--.': 'G',
 '--.-': 'Q',
 '--..': 'Z',
 '-.': 'N',
 '-.-': 'K',
 '-.--': 'Y',
 '-.-.': 'C',
 '-..': 'D',
 '-..-': 'X',
 '-...': 'B',
 '.': 'E',
 '.-': 'A',
 '.--': 'W',
 '.---': 'J',
 '.--.': 'P',
 '.-.': 'R',
 '.-..': 'L',
 '..': 'I',
 '..-': 'U',
 '..-.': 'F',
 '...': 'S',
 '...-': 'V',
 '....': 'H',
 '/': ' '}

# %%
to_es['/']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-0d0c1ed0d7a9> in <module>()
# ----> 1 to_es['/']
#
# KeyError: '/'

# %%
def traductor_a_espanol(mensaje_a_traducir):
    abc_es = {'-': 'T',
     '--': 'M',
     '---': 'O',
     '--.': 'G',
     '--.-': 'Q',
     '--..': 'Z',
     '-.': 'N',
     '-.-': 'K',
     '-.--': 'Y',
     '-.-.': 'C',
     '-..': 'D',
     '-..-': 'X',
     '-...': 'B',
     '.': 'E',
     '.-': 'A',
     '.--': 'W',
     '.---': 'J',
     '.--.': 'P',
     '.-.': 'R',
     '.-..': 'L',
     '..': 'I',
     '..-': 'U',
     '..-.': 'F',
     '...': 'S',
     '...-': 'V',
     '....': 'H',
     '/': ' '}
    
    mensaje_a_traducir_splitted = mensaje_a_traducir.split()
    mensaje_traducido = ''
    for letra_en_morse in mensaje_a_traducir_splitted:
        mensaje_traducido += abc_es[letra_en_morse]
    
    return mensaje_traducido
